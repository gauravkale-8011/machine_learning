# %%
import pandas as pd
import numpy as np
import pickle

# %%
pipe=pickle.load(open("models/pipes.pkl","rb"))

# %%
test_input=np.array([2,"male",31.0,1,1,32.00,"S"]).reshape(1,7)

# %%
pipe.predict(test_input)
# Out:
# C:\Users\kaleg\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# C:\Users\kaleg\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
