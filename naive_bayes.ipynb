# %%
import pandas as pd

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("play_tennis.csv")

# %%
df.head()
# Out:
#   day   outlook  temp humidity    wind play
# 0  D1     Sunny   Hot     High    Weak   No
# 1  D2     Sunny   Hot     High  Strong   No
# 2  D3  Overcast   Hot     High    Weak  Yes
# 3  D4      Rain  Mild     High    Weak  Yes
# 4  D5      Rain  Cool   Normal    Weak  Yes

# %%
df.drop(columns=["day"],inplace=True)

# %%
df
# Out:
#      outlook  temp humidity    wind play
# 0      Sunny   Hot     High    Weak   No
# 1      Sunny   Hot     High  Strong   No
# 2   Overcast   Hot     High    Weak  Yes
# 3       Rain  Mild     High    Weak  Yes
# 4       Rain  Cool   Normal    Weak  Yes
# 5       Rain  Cool   Normal  Strong   No
# 6   Overcast  Cool   Normal  Strong  Yes
# 7      Sunny  Mild     High    Weak   No
# 8      Sunny  Cool   Normal    Weak  Yes
# 9       Rain  Mild   Normal    Weak  Yes
# 10     Sunny  Mild   Normal  Strong  Yes
# 11  Overcast  Mild     High  Strong  Yes
# 12  Overcast   Hot   Normal    Weak  Yes
# 13      Rain  Mild     High  Strong   No

# %%
# problem 1
#outlook=Sunny, temp=hot , humidith=high , wind=weak
# play or no play?

# %%
#solution
#p(yes/Sunny,hot,high,weak)=p(sunny/yes) * p(hot/yes) * p(high/yes) * p(weak/yes) * p(yes)

#p(no/Sunny,hot,high,weak)=p(sunny/no) * p(hot/no) * p(high/no) * p(weak/no) * p(no)

# compare and decide using the maximum posteriori rule

# %%
df["play"].value_counts()
# Out:
# play
# Yes    9
# No     5
# Name: count, dtype: int64

# %%
pyes=9/14
pno=5/14

# %%
#outlook
pd.crosstab(df["outlook"],df["play"])
# Out:
# play      No  Yes
# outlook
# Overcast   0    4
# Rain       2    3
# Sunny      3    2

# %%
psunnyy=3/9
povercasty=4/9
prainy=2/9

psunnyn=2/5
povercastn=0
prainn=3/5

# %%
#temp
pd.crosstab(df["temp"],df["play"])
# Out:
# play  No  Yes
# temp
# Cool   1    3
# Hot    2    2
# Mild   2    4

# %%
pcooly=3/9
photy=2/9
pmildy=4/9

pcooln=1/5
photn=2/5
pmildn=4/5

# %%
#humidity
pd.crosstab(df["humidity"],df["play"])
# Out:
# play      No  Yes
# humidity
# High       4    3
# Normal     1    6

# %%
phighy=3/9
pnormaly=6/9

phighn=4/5
pnormaln=1/5

# %%
#wind
pd.crosstab(df["wind"],df["play"])
# Out:
# play    No  Yes
# wind
# Strong   3    3
# Weak     2    6

# %%
pstrongy=3/14
pweaky=6/14

pstrongn=3/5
pweakn=2/5

# %%
#outlook=Sunny, temp=hot , humidith=high , wind=weak
pyes_=psunnyy*photy*phighy*pweaky*pyes
pyes_
# Out:
# 0.006802721088435374

# %%
pno_=psunnyn*photn*phighn*pweakn*pno
pno_
# Out:
# 0.01828571428571429

# %%
#so basically the prob of no is high that's why output will bw no
